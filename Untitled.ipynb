# %%
from os.path import join
from pathlib import Path
import pandas as pd
import numpy as np

# %%
output_base_dir = r"C:\Users\eliran.shmi\Documents\Thesis\dataset"

# %%
output_base_dir = Path(output_base_dir)

# %%
output_base_dir / "tiles_dataset"
# Out:
# WindowsPath('C:/Users/eliran.shmi/Documents/Thesis/dataset/tiles_dataset')

# %%
csv_dir = "CSVs"

# %%
slides_file_name = "SlidesZohar.xlsx"

# %%
slides_df = pd.read_excel(join(csv_dir, slides_file_name))

# %%
sorted(slides_df["SlideFile#"].unique())
# Out:
# ['1M01',
#  '1M02',
#  '1M03',
#  '1M04',
#  '1M05',
#  '1M06',
#  '1M07',
#  '1M08',
#  '1M09',
#  '1M10',
#  '1M11',
#  '1M12',
#  '1M13',
#  '1M14',
#  '1M15',
#  '1M16',
#  '1M17',
#  '1M18',
#  '1M19',
#  '1M20',
#  '1M21',
#  '1M22',
#  '1M23',
#  '1M24',
#  '1M25',
#  '2M01',
#  '2M02',
#  '2M22',
#  '3M20',
#  '3M21',
#  '3M23',
#  '3M24',
#  '3M25',
#  '4M01',
#  '4M02',
#  '4M03',
#  '4M04',
#  '4M05',
#  '4M06',
#  '4M07',
#  '4M08',
#  '4M09',
#  '4M10',
#  '4M11',
#  '4M12',
#  '4M13',
#  '4M14',
#  '4M15',
#  '4M16',
#  '4M17',
#  '4M18',
#  '4M20',
#  '4M21',
#  '4M22',
#  '4M23',
#  '4M24',
#  '4M25',
#  '5M01',
#  '5M02',
#  '5M03',
#  '5M04',
#  '5M05',
#  '5M06',
#  '5M07',
#  '5M08']

# %%
# Out:
# 66
